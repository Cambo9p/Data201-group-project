# %% [markdown]
# This file will import the crash analysis data and sort it by location
# (into the christchurch/canterbury reigon)

# %%
library(tidyverse)
# Out:
# ── Attaching packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.0      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.1
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# import the csv data from the file into R 
crash_data <- read_csv(file = "crash_data.csv") 
crash_data
# Out:
# Rows: 801911 Columns: 72
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (20): crashDirectionDescription, crashFinancialYear, crashLocation1, cra...
# dbl (50): X, Y, OBJECTID, advisorySpeed, areaUnitID, bicycle, bridge, bus, c...
# lgl  (2): crashRoadSideRoad, intersection
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#        X       Y       OBJECTID advisorySpeed areaUnitID bicycle bridge bus
# 1      1808645 5819854  1       NA            527125     0        0     0
# 2      1569263 5177269  2       NA            595000     0       NA     0
# 3      1392831 4908393  3       NA            602000     0        0     0
# 4      1394050 4916036  4       NA            606210     0       NA     0
# ...

# %%
unique(crash_data$region)
# Out:
#  [1] "Waikato Region"            "Canterbury Region"
#  [3] "Otago Region"              "Wellington Region"
#  [5] "Auckland Region"           "Hawke's Bay Region"
#  [7] "Manawatū-Whanganui Region" "Tasman Region"
#  [9] "West Coast Region"         "Taranaki Region"
# [11] "Nelson Region"             "Gisborne Region"
# [13] "Bay of Plenty Region"      "Southland Region"
# [15] "Northland Region"          "Marlborough Region"
# [17] ""

# %%
# this function will return a vector containing the matches to the regex 
# which searches through the rows in the dataframe
region_vector <- function(df) {
    
    search_regex = "canterbury|christchurch|chch" # the regex to match the regions - can be changed to add other regions 
    df <- df %>% mutate_at('region', ~replace_na(.,"")) # replace na values with an empty string
    
    matches = vector()
    for (i in unique(df$region)) {
        
        if (str_detect(i, regex(search_regex, ignore_case = TRUE))){
            matches <- append(matches, i)
            
        }
    }
    matches
}
re_matches <- region_vector(crash_data)
re_matches
# Out:
# [1] "Canterbury Region"

# %%
# now filter the crash data so it only shows crashes in christchurch/canterbury
chch_crashes = crash_data %>% filter(region %in% re_matches)
chch_crashes
# Out:
#       X       Y       OBJECTID advisorySpeed areaUnitID bicycle bridge bus
# 1     1569263 5177269   2      NA            595000     0       NA     0
# 2     1554448 5181256   6      NA            587821     0        0     0
# 3     1549322 5285349   7      NA            585506     0       NA     0
# 4     1572260 5180996   8      NA            593300     0       NA     0
# 5     1573557 5180808  16      NA            593600     0       NA     0
# 6     1573407 5180049  22      NA            593600     0       NA     0
# 7     1568675 5183354  27      NA            592100     0       NA     0
# 8     1571851 5182759  30      NA            592701     0       NA     0
# 9     1498260 5140456  33      NA            597811     0        0     0
# 10    1577339 5182974  36      NA            595700     0        0     0
# 11    1570646 5178931  37      NA            594600     0       NA     0
# 12    1564093 5180578  38      NA            589900     0       NA     0
# ...

# %% [markdown]
# now we want to download the chch crash data to create our data model

# %%
# this writes the raw data to the chch_crashes.csv file 
write.csv(chch_crashes, "chch_crashes.csv")
